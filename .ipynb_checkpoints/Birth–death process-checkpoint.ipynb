# %% [markdown]
# # Birth–death process

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ### Initial values

# %%
n = 5

# %%
state_matrix = np.zeros((n,n))
left = np.zeros(n)
right = np.zeros(n)
for i in range(n-1):
    #left[i] = np.random.random()
    #right[i] = np.random.random()
    left[i] = np.random.randint(1,100)
    right[i] = np.random.randint(1, 100)
#right = np.array([3.75,2.5,1.65,5.65])
#left = np.array([4.2,5.45,3.3,2.85])
upper_diagonal = np.diagonal(state_matrix,offset=1)
bottom_diagonal = np.diagonal(state_matrix,offset=-1)
upper_diagonal.setflags(write = True)
bottom_diagonal.setflags(write = True)
for i in range(n-1):
    upper_diagonal[i]=right[i]
    bottom_diagonal[i]=left[i]

# %%
state_matrix
# Out:
# array([[ 0., 71.,  0.,  0.,  0.],
#        [32.,  0., 16.,  0.,  0.],
#        [ 0., 22.,  0., 12.,  0.],
#        [ 0.,  0., 99.,  0., 14.],
#        [ 0.,  0.,  0., 33.,  0.]])

# %% [markdown]
# ### Analytical solution

# %%
alpha = np.zeros(n)
p = np.zeros(n)
for i in range(n):
    alpha[i] = np.prod(right[:i])/np.prod(left[:i])
p = np.zeros(n)
p[0] = 1/(1+sum(alpha[1:]))
for i in range(n-1):
    p[i+1] = p[0]*alpha[i+1]

# %%
p
# Out:
# array([0.19565807, 0.43411633, 0.31572097, 0.03826921, 0.01623542])

# %% [markdown]
# ## via Kolmogorov

# %%
coefficient_matrix = state_matrix.copy()
upper_diagonal = np.diagonal(coefficient_matrix,offset=1)
bottom_diagonal = np.diagonal(coefficient_matrix,offset=-1)
upper_diagonal.setflags(write = True)
bottom_diagonal.setflags(write = True)
for i in range(n-1):
    coefficient_matrix[i][i]-=upper_diagonal[i]
for i in range(n-1):
    coefficient_matrix[i+1][i+1]-=bottom_diagonal[i]
for i in range(n-1):
    upper_diagonal[i],bottom_diagonal[i] = bottom_diagonal[i],upper_diagonal[i]

# %%
coefficient_matrix
# Out:
# array([[ -71.,   32.,    0.,    0.,    0.],
#        [  71.,  -48.,   22.,    0.,    0.],
#        [   0.,   16.,  -34.,   99.,    0.],
#        [   0.,    0.,   12., -113.,   33.],
#        [   0.,    0.,    0.,   14.,  -33.]])

# %%
eigenvalues = np.linalg.eig(coefficient_matrix)[0]
eigenvectors = np.linalg.eig(coefficient_matrix)[1]
for i in range(n):
    t1 = []
    p1 = []
    for j in range(n):
        p1.append([0])
    p1[i]=[1]
    c = np.linalg.solve(eigenvectors,[i[0] for i in p1])
    for j in tqdm(np.linspace(0, 1, num=10000)):
        t1.append(j)
        for k in range(n):
            p1[k].append(0)
            for l in range(n):
                p1[k][-1]+=c[l]*eigenvectors[k][l]*np.exp(eigenvalues[l]*j)
                #p1[k][-1]+=c[l]*eigenvectors[l][k]*np.exp(eigenvalues[l]*j)
    print('start',[j[0] for j in p1])
    print('end  ',[j[-1] for j in p1])
    plt.figure(figsize=(20,10))
    for m in range(n):
        plt.plot(t1,p1[m][:-1], linewidth=3)
        plt.legend(['p'+str(i+1) for i in range(n)])
    plt.show()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 12949.58it/s]
# start [1, 0, 0, 0, 0]
# end   [0.19565806594203541, 0.43411633379943143, 0.31572097000152605, 0.038269208482019805, 0.016235421774990613]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 12548.46it/s]
# start [0, 1, 0, 0, 0]
# end   [0.19565806593777213, 0.4341163337930283, 0.31572097000799065, 0.038269208483777004, 0.016235421777435522]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 12341.94it/s]
# start [0, 0, 1, 0, 0]
# end   [0.19565806591643917, 0.4341163337609876, 0.3157209700403385, 0.03826920849256979, 0.01623542178966953]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 12107.87it/s]
# start [0, 0, 0, 1, 0]
# end   [0.1956580659010312, 0.43411633373784564, 0.3157209700637006, 0.03826920849892021, 0.01623542179850546]
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 9395.67it/s]
# start [0, 0, 0, 0, 1]
# end   [0.19565806583763873, 0.43411633364263436, 0.31572097015982337, 0.03826920852504858, 0.01623542183486002]

# %% [markdown]
# ##  via Simulation

# %%
for i in range(n):
    counts = np.zeros(n)
    p2 = []
    t2 = np.zeros(n)
    for j in range(n):
        p2.append([0])
    counts[i]=1
    position = i
    p2[i] = [1]
    for j in tqdm(range(1,10001)):
        generate = np.random.exponential(1/state_matrix[position])
        t2[position]+=np.min(generate)
        position = np.argmin(generate)
        for k in range(n):
            p2[k].append(t2[k]/sum(t2))  
    print('start',[j[0] for j in p2])
    print('end  ',[j[-1] for j in p2]) 
    plt.figure(figsize=(20,10))
    for m in range(n):
        plt.plot(p2[m], linewidth=3)
        plt.legend(['p'+str(i+1) for i in range(n)])
    plt.show()
# Out:
#   0%|                                                                                        | 0/10000 [00:00<?, ?it/s]C:\Users\Lepsky\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 20411.37it/s]
# start [1, 0, 0, 0, 0]
# end   [0.19822421102856172, 0.4278349751378053, 0.31392320698304366, 0.04275401607441167, 0.017263590776177857]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 20923.92it/s]
# start [0, 1, 0, 0, 0]
# end   [0.19239537183771205, 0.43136846195268125, 0.31919111996459126, 0.038757456717766516, 0.018287589527248946]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 25449.27it/s]
# start [0, 0, 1, 0, 0]
# end   [0.19165152316969797, 0.43609541011145425, 0.31520313015422424, 0.041502000278856206, 0.01554793628576743]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 22939.37it/s]
# start [0, 0, 0, 1, 0]
# end   [0.19913423229051117, 0.431814343728858, 0.3139022370804088, 0.03795449082589104, 0.017194696074330912]
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 27030.00it/s]
# start [0, 0, 0, 0, 1]
# end   [0.1975142450058554, 0.4329874229996977, 0.31420132228385256, 0.0376075850269353, 0.017689424683658847]

# %% [markdown]
# ### Total result

# %%
for i in range(n):
    print('p'+str(i+1),round(p[i],5),round(p1[i][-1],5),round(p2[i][-1],5))
# Out:
# p1 0.19566 0.19566 0.19751
# p2 0.43412 0.43412 0.43299
# p3 0.31572 0.31572 0.3142
# p4 0.03827 0.03827 0.03761
# p5 0.01624 0.01624 0.01769

# %%
for i in range(n):
    error_loss1 = [abs(j-p[i]) for j in p1[i]]
    error_loss2 = [abs(j-p[i]) for j in p2[i]]
    plt.figure(figsize=(20,5))
    plt.subplot(1,2,1)
    plt.plot(error_loss1, linewidth=3)
    plt.subplot(1,2,2)
    plt.plot(error_loss2, linewidth=3)
    plt.show()
